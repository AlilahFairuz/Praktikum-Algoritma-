# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 9 Oktober 2025
Tugas 4 : Lat. 1 - Buatlah program dengan keluaran output seperti dibawah ini menggunakan perulangan for
"""

for i in range(7, 0, -1):
  print (str(i) * i)
# Out:
# 7777777
# 666666
# 55555
# 4444
# 333
# 22
# 1

# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 9 Oktober 2025
Tugas 4 : Lat. 2 - Perulangan while
"""

bulan = int(input("Masukkan bulan (1–12):"))
while bulan < 1 or bulan > 12:
    print("Bulan tidak valid! Coba lagi")
    bulan = int(input("Masukkan bulan (1–12): "))

tahun = int(input("Masukkan tahun: "))

if bulan in [1, 3, 5, 7, 8, 10, 12]:
    hari = 31
elif bulan in [4, 6, 9, 11]:
    hari = 30
else:
    if (tahun % 4 == 0 and tahun % 100 != 0) or (tahun % 400 == 0):
        hari = 29
    else:
        hari = 28

print(f"Jumlah hari pada bulan {bulan} tahun {tahun} adalah {hari} hari.")
# Out:
# Masukkan bulan (1–12):3
# Masukkan tahun: 2015
# Jumlah hari pada bulan 3 tahun 2015 adalah 31 hari.
