# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 02 oktober 2025
Tugas 3 : Latihan 1 - Menentukan Jenis Segitiga
"""

print("Menentukan Jenis Segitiga")

a = float(input("Masukkan panjang sisi a:"))
b = float(input("Masukkan panjang sisi b:"))
c = float(input("Masukkan panjang sisi c:"))

if a + b <= c or a + c <= b or b + c <= a:
    print("Bukan segitiga")

elif a == b == c:
    print("Segitiga sama sisi")

elif a == b or a == c or b == c:
    print("Segitiga sama kaki")

elif a ** 2 == b ** 2 + c ** 2 or b ** 2 == a ** 2 + c ** 2 or c ** 2 == a ** 2 + b ** 2:
    print("Segitiga siku-siku")

else:
    print("Segitiga sembarang")
# Out:
# Menentukan Jenis Segitiga
# Masukkan panjang sisi a:6
# Masukkan panjang sisi b:8
# Masukkan panjang sisi c:10
# Segitiga siku-siku

# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 02 oktober 2025
Tugas 3 : Latihan 2 - Program pembayaran belanjaan dengan ada diskon dan kupon
"""

print("Program Perhitungan Diskonan Pembelanjaan USAKTIF")
nama = input("Masukan Nama:")
NIM = input("Masukan NIM:")
total_belanja = int(input("Masukan Total Belanja anda: Rp"))
pakai_kupon = input("Bayar pakai kupon? y/n:")

potongan = 0
diskon = 0
total_bayar = total_belanja

if pakai_kupon.lower() == "y":
    kode = input("Masukan kode kupon:")
    if kode == "IKL6309":
        print("SELAMAT! ANDA MENDAPATKAN DISKON 100% (GRATIS)")
        potongan = total_belanja
        total_bayar = 0
    else:
        print("KODE KUPON SALAH / EXPIRED")
        total_bayar = total_belanja

else:
  if total_belanja >= 390000:
    diskon = 80
  elif total_belanja >= 190000:
    diskon = 60
  elif total_belanja >= 90000:
    diskon = 40
  elif total_belanja >= 40000:
    diskon = 20
  else:
    diskon = 0

  potongan = total_belanja * (diskon / 100)
  total_bayar = total_belanja - potongan

  if diskon == 0:
    print("ANDA TIDAK MENDAPATKAN DISKON")
  else:
    print(f"SELAMAT ANDA MENDAPATKAN DISKON {diskon}%")

print(f"Total yang harus dibayar: Rp {total_bayar}")
print("Terima Kasih Sudah Berbelanja di USAKTIF")
# Out:
# Program Perhitungan Diskonan Pembelanjaan USAKTIF
# Masukan Nama:Alilah Fairuz Rafifah
# Masukan NIM:065002500022
# Masukan Total Belanja anda: Rp150000
# Bayar pakai kupon? y/n:y
# Masukan kode kupon:IKL123
# KODE KUPON SALAH / EXPIRED
# Total yang harus dibayar: Rp 150000
# Terima Kasih Sudah Berbelanja di USAKTIF
