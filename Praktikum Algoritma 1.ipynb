# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 18 September 2025
Tugas : Program untuk menampilkan data alamat
"""

print("")
print("Masukkan data kamu dengan sesuai")
nama = input("nama:")
alamat = input("alamat:")
nama_kampus = input("nama_kampus:")
jurusan = input("jurusan:")
gedung = input("gedung:")
print("")

print(f"Halo nama saya {nama}, saya tinggal di {alamat}, saya kuliah di {nama_kampus}, jurusan saya {jurusan}, di gedung {gedung}, dan saya siap ikuti praktikum algoritma")
# Out:
# Masukkan data kamu dengan sesuai
# nama:Alilah Fairuz Rafifah
# alamat:Jakarta
# nama_kampus:Trisakti
# jurusan:Sistem Informasi
# gedung:E
#
# Halo nama saya Alilah Fairuz Rafifah, saya tinggal di Jakarta, saya kuliah di Trisakti, jurusan saya Sistem Informasi, di gedung E, dan saya siap ikuti praktikum algoritma

# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 18 September 2025
Tugas : Menghitung Luas Ruangan
"""

print("Menghitung Luas Ruangan")
pr = int(input("Masukkan panjang ruangan:"))
lr = int(input("Masukkan lebar ruangan:"))
rumus_meter = pr * lr
rumus_inch = (pr * 39.37) * (lr * 39.37)

print("")
print(f"Luas ruangan dengan panjang {pr} dan lebar {lr} adalah {rumus_meter} meter atau {rumus_inch} inch")
# Out:
# Menghitung Luas Ruangan
# Masukkan panjang ruangan:8
# Masukkan lebar ruangan:5
#
# Luas ruangan dengan panjang 8 dan lebar 5 adalah 40 meter atau 61999.876 inch
