# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 30 Oktober 2025
Tugas 5 : Buatlah program fungsi untuk merata-ratakan nilai sesuai dengan kategori huruf yang diinputkan
"""

total = 0
jumlah = 0

while True:
    huruf = input("masukkan nilai: ").upper()

    if huruf == "":
        break

    if huruf == "A":
        nilai = 4.00
    elif huruf == "A-":
        nilai = 3.75
    elif huruf == "B+":
        nilai = 3.50
    elif huruf == "B":
        nilai = 3.00
    elif huruf == "B-":
        nilai = 2.75
    elif huruf == "C+":
        nilai = 2.50
    elif huruf == "C":
        nilai = 2.00
    elif huruf == "C-":
        nilai = 1.75
    elif huruf == "D":
        nilai = 1.50
    elif huruf == "E":
        nilai = 1.25
    else:
        print("Input tidak valid. Silakan coba lagi.")

    print(f"nilai = {nilai}")
    total += nilai
    jumlah += 1

if jumlah > 0:
    rata = total / jumlah
    print(f"Rata - rata nya adalah: {rata:.2f}")
else:
    print("Tidak ada nilai yang dimasukkan.")
# Out:
# masukkan nilai: A
# nilai = 4.0
# masukkan nilai: A-
# nilai = 3.75
# masukkan nilai: B+
# nilai = 3.5
# masukkan nilai: B
# nilai = 3.0
# masukkan nilai: B-
# nilai = 2.75
# masukkan nilai: C+
# nilai = 2.5
# masukkan nilai: C
# nilai = 2.0
# masukkan nilai: C-
# nilai = 1.75
# masukkan nilai: D
# nilai = 1.5
# masukkan nilai: E
# nilai = 1.25
# masukkan nilai:
# Rata - rata nya adalah: 2.60

# %%
"""
Nama : Alilah Fairuz Rafifah
NIM : 065002500022
Tanggal : Kamis, 30 Oktober 2025
Tugas 5 : Program Untuk Menghitung Tiket Masuk Kebun Binatang
"""

total = 0

while True:
    umur = input("masukkan umur: ")

    if umur == "":
        break
    umur = int(umur)

    if umur <= 2:
        harga = 0
        print("Gratis")
    elif 3 <= umur <= 12:
        harga = 14
        print("Harga $14.00")
    elif umur >= 65:
        harga = 18
        print("Harga $18.00")
    else:
        harga = 23
        print("Harga $23.00")

    total += harga
    print(f"Running total: {total:.2f}")

uang = float(input("masukkan jumlah uang: "))
kembalian = uang - total
print(f"Running kembalian: {kembalian:.2f}")
# Out:
# masukkan umur: 1
# Gratis
# Running total: 0.00
# masukkan umur: 10
# Harga $14.00
# Running total: 14.00
# masukkan umur: 20
# Harga $23.00
# Running total: 37.00
# masukkan umur: 70
# Harga $18.00
# Running total: 55.00
# masukkan umur:
# masukkan jumlah uang: 100
# Running kembalian: 45.00

# %%
umur = int(input("Masukkan umur: "))

if umur >= 18:
    print("Kamu sudah dewasa")
    if umur >= 65:
        print("Kamu termasuk lansia")
    else:
        print("Kamu dewasa tetapi belum lansia")
else:
    print("Kamu masih anak-anak")
# Out:
# Masukkan umur: 19
# Kamu sudah dewasa
# Kamu dewasa tetapi belum lansia
